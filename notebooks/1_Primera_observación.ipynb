# %%
import numpy as np
import pandas as pd

# %%
url = r'C:\Users\nuria\Proyecto_EDA\data\raw\Student Depression Dataset.csv'

# %% [markdown]
# ### 1. Inspeccionar el tamaño y estructura de los datos

# %%
df = pd.read_csv(r'C:\Users\nuria\Proyecto_EDA\data\raw\Student Depression Dataset.csv')
df
# CGPA: Promedio de calificaciones u otros puntajes académicos.
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.set_index('id')
# Out:
#         Gender   Age           City Profession  Academic Pressure  \
# id
# 2         Male  33.0  Visakhapatnam    Student                5.0
# 8       Female  24.0      Bangalore    Student                2.0
# 26        Male  31.0       Srinagar    Student                3.0
# 30      Female  28.0       Varanasi    Student                3.0
# 32      Female  25.0         Jaipur    Student                4.0
# ...        ...   ...            ...        ...                ...
# 140685  Female  27.0          Surat    Student                5.0
# 140686    Male  27.0       Ludhiana    Student                2.0
# 140689    Male  31.0      Faridabad    Student                3.0
# 140690  Female  18.0       Ludhiana    Student                5.0
# 140699    Male  27.0          Patna    Student                4.0
#
#         Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# id
# 2                 0.0  8.97                 2.0               0.0
# ...

# %% [markdown]
# Este conjunto de datos contiene 18 variables (columnas) y 27901 filas

# %%
# Verificar si hay jerarquías o estructuras anidadas
# Comprobar si hay listas o diccionarios en alguna columna
for column in df.columns:
    if df[column].apply(lambda x: isinstance(x, (list, dict))).any():
        print(f"La columna '{column}' tiene estructuras anidadas.")

# %% [markdown]
# No hay jerarquías ni estructuras anidadas

# %% [markdown]
# ### 2. Verificar tipos de datos y nombres de columnas

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression',
#        'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %% [markdown]
# No hay valores nulos

# %% [markdown]
# |Columna| Descripción| Tipo de dato|
# |---|---|---|
# |id|id|int|
# |Gender|Genero|str|
# |Age|Edad|int|
# |City|Ciudad|str|
# |Profession|Profesión|str|
# |Academic Pressure|Presión académica|float|
# |Work Pressure|Presión laboral|float|
# |CGPA|Promedio de calificaciones u otros puntajes académicos|float|
# |Study Satisfaction|Satisfacción de estudio|float|
# |Job Satisfaction|Satisfacción de trabajo|float|
# |Sleep Duration|Duración de sueño|str|
# |Dietary Habits|Dieta|str|
# |Degree|Año de estudios|str|
# |Have you ever had suicidal thoughts?|¿Alguna vez has tenidos pensamientos suicidas?|str|
# |Work/Study Hours|Horas de trabajo/estudio|float|
# |Financial Stress|Estres economico|float|
# |Family History of Mental Illness|Antecedentes familiares de enfermedad mental|str|
# |Depression|Depresión|int|

# %% [markdown]
# Obsevaciones
# - Memoria: 3.8+ MB
# - La edad sale como flotante
# - Sleep durantion sale tipo object
# - Todos los textos salen tipo object pero llaman la atención 'Gender' y 'Have you ever had suicidal thoughts?'

# %% [markdown]
# ### 3. Identificar valores duplicados o errores evidentes

# %%
duplicados = df.duplicated()
duplicados.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
# Observamos que tenga valores missing
df[df.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [id, Gender, Age, City, Profession, Academic Pressure, Work Pressure, CGPA, Study Satisfaction, Job Satisfaction, Sleep Duration, Dietary Habits, Degree, Have you ever had suicidal thoughts ?, Work/Study Hours, Financial Stress, Family History of Mental Illness, Depression, Country]
# Index: []

# %% [markdown]
# No tenemos valores duplicados exactos ni valores missing

# %%
df.isnull().sum()
# Out:
# id                                           0
# Gender                                       0
# Age                                          0
# City                                         0
# Profession                                   0
# Academic Pressure                            0
# Work Pressure                                0
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                             0
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             3
# Family History of Mental Illness             0
# Depression                                   0
# Country                                  27901
# dtype: int64

# %%
df.nunique()
# Out:
# id                                       27901
# Gender                                       2
# Age                                         34
# City                                        52
# Profession                                  14
# Academic Pressure                            6
# Work Pressure                                3
# CGPA                                       332
# Study Satisfaction                           6
# Job Satisfaction                             5
# Sleep Duration                               5
# Dietary Habits                               4
# Degree                                      28
# Have you ever had suicidal thoughts ?        2
# Work/Study Hours                            13
# Financial Stress                             5
# Family History of Mental Illness             2
# Depression                                   2
# Country                                      0
# dtype: int64

# %%
df.groupby('City')

# %%
city_counts = df.groupby('City').size()
print(city_counts)
# Out:
# City
# 3.0                      1
# Agra                  1094
# Ahmedabad              951
# Bangalore              767
# Bhavna                   2
# Bhopal                 934
# Chennai                885
# City                     2
# Delhi                  768
# Faridabad              461
# Gaurav                   1
# Ghaziabad              745
# Harsh                    1
# Harsha                   2
# Hyderabad             1340
# Indore                 643
# Jaipur                1036
# Kalyan                1570
# Kanpur                 609
# Khaziabad                1
# Kibara                   1
# Kolkata               1066
# Less Delhi               1
# Less than 5 Kalyan       1
# Lucknow               1155
# Ludhiana              1111
# M.Com                    1
# M.Tech                   1
# ME                       1
# Meerut                 825
# Mihir                    1
# Mira                     1
# Mumbai                 699
# Nagpur                 651
# ...

# %%
city_means = df.groupby('City')['Depression'].mean()
print(city_means)
# Calcula la media de otras columnas agrupandolas por cuidad
# Out:
# City
# 3.0                   1.000000
# Agra                  0.534735
# Ahmedabad             0.672976
# Bangalore             0.608866
# Bhavna                1.000000
# Bhopal                0.619914
# Chennai               0.596610
# City                  0.500000
# Delhi                 0.609375
# Faridabad             0.587852
# Gaurav                1.000000
# Ghaziabad             0.574497
# Harsh                 1.000000
# Harsha                0.500000
# Hyderabad             0.669403
# Indore                0.604977
# Jaipur                0.524131
# Kalyan                0.594904
# Kanpur                0.541872
# Khaziabad             1.000000
# Kibara                0.000000
# Kolkata               0.608818
# Less Delhi            0.000000
# Less than 5 Kalyan    0.000000
# Lucknow               0.554978
# Ludhiana              0.582358
# M.Com                 1.000000
# M.Tech                0.000000
# ME                    0.000000
# Meerut                0.597576
# ...

# %% [markdown]
# ## Observaciones
# - El conjunto de datos se compone de 18 columnas (variables) y 27901 filas
# - Utiliza un espacio de memoria de 3.5+ MB
# - Solo hay valores nulos en 'Financial Stress'
# - No hay valores duplicados
# - No hay datos faltantes
# - Hay algunos tipos de dato que probablemente tenga que cambiar
# - No hay jerarquías o estructuras anidadas

# %%
df = df.drop(columns=['Job Satisfaction'])
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df = df.drop(columns=['Job Satisfaction'])
#       2 print(df.head())
#
# File c:\Users\nuria\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df = df.drop(columns=['Work Pressure'])

# %%
df.head(2)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1   8  Female  24.0      Bangalore    Student                2.0  5.90
#
#    Study Satisfaction Sleep Duration Dietary Habits   Degree  \
# 0                 2.0      5-6 hours        Healthy  B.Pharm
# 1                 5.0      5-6 hours       Moderate      BSc
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                   Yes               3.0               1.0
# 1                                    No               3.0               2.0
#
#   Family History of Mental Illness  Depression Country
# 0                               No           1     NaN
# 1                              Yes           0     NaN

# %%
# Guarda el dataframe en una archivo CSV nuevo (sin las columnas eliminadas)
df.to_csv(r'C:\Users\nuria\Proyecto_EDA\data\raw\Student Depression Dataset sin job satisfaction.csv', index='id')

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        CGPA  Study Satisfaction     Sleep Duration Dietary Habits    Degree  \
# ...
